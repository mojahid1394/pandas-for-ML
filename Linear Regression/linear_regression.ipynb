# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('xyz.csv', sep=';')
df
# Out:
#         Date  Starting (USD)  Ending (USD)
# 0   01.01.24           16800         16500
# 1   01.12.23           15900         16100
# 2   01.11.23           15800         15300
# 3   01.10.23           16100         16200
# 4   01.09.23           16300         15700
# 5   01.08.23           16800         16400
# 6   01.07.23           15900         16200
# 7   01.06.23           15800         15500
# 8   01.05.23           16150         16100
# 9   01.04.23           16300         15800
# 10  01.03.23           16200         16200
# 11  01.02.23           16300         15700

# %%
df.head()
# Out:
#        Date  Starting (USD)  Ending (USD)
# 0  01.01.24           16800         16500
# 1  01.12.23           15900         16100
# 2  01.11.23           15800         15300
# 3  01.10.23           16100         16200
# 4  01.09.23           16300         15700

# %%
df.isnull().sum()
# Out:
# Date              0
# Starting (USD)    0
# Ending (USD)      0
# dtype: int64

# %%
df.drop('Date', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Starting (USD)  Ending (USD)
# 0           16800         16500
# 1           15900         16100
# 2           15800         15300
# 3           16100         16200
# 4           16300         15700

# %%
plt.scatter(df['Starting (USD)'], df['Ending (USD)'])
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('XYZ Stock Price')
# Out:
# Text(0.5, 1.0, 'XYZ Stock Price')

# %%
x = df.drop('Ending (USD)', axis=1)
x.head()
# Out:
#    Starting (USD)
# 0           16800
# 1           15900
# 2           15800
# 3           16100
# 4           16300

# %%
y = df[['Ending (USD)']]
y.head()
# Out:
#    Ending (USD)
# 0         16500
# 1         16100
# 2         15300
# 3         16200
# 4         15700

# %%
reg = LinearRegression()

# %%
x.mean()
# Out:
# Starting (USD)    16195.833333
# dtype: float64

# %%
y.mean()
# Out:
# Ending (USD)    15975.0
# dtype: float64

# %%
plt.scatter(x.mean(), y.mean(), color='red', marker='+')
plt.scatter(df['Starting (USD)'], df['Ending (USD)'])
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('XYZ Stock Price')
# Out:
# Text(0.5, 1.0, 'XYZ Stock Price')

# %% [markdown]
# **Train the ML model**

# %%
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
m = reg.coef_
m
# Out:
# array([[0.65258293]])

# %%
c = reg.intercept_
c
# Out:
# array([5405.87555702])

# %%
# y = mx + c
m * 16700 + c
# Out:
# array([[16304.0105628]])

# %%
reg.predict([[16700]])
# Out:
# c:\Users\mojah\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2830: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[16304.0105628]])

# %%
df['Predicted_y'] = reg.predict(x)
df.head()
# Out:
#    Starting (USD)  Ending (USD)   Predicted_y
# 0           16800         16500  16369.268856
# 1           15900         16100  15781.944215
# 2           15800         15300  15716.685922
# 3           16100         16200  15912.460802
# 4           16300         15700  16042.977389

# %%
plt.scatter(x.mean(), y.mean(), color='red', marker='+')
plt.plot(x, reg.predict(x))
plt.scatter(df['Starting (USD)'], df['Ending (USD)'])
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('XYZ Stock Price')
# Out:
# Text(0.5, 1.0, 'XYZ Stock Price')

# %%
reg.predict([[16600]])
# Out:
# c:\Users\mojah\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2830: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[16238.75226935]])
