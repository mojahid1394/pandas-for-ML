# %%
import pandas as pd
import numpy as np

# %%
stuff = {
    'Corporation':['Apple', 'Google', 'Meta', 'Apple', 'Google','Meta'],
    'Employees':['John', 'April', 'Wes', 'Beth', 'Justin', 'Steph'],
    'Salary':[200, 220, 190, 130, 120, 150],
}
df = pd.DataFrame(stuff)
df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %% [markdown]
# **Sort salarys from lowest to highest**

# %%
df.sort_values('Salary')
# Out:
#   Corporation Employees  Salary
# 4      Google    Justin     120
# 3       Apple      Beth     130
# 5        Meta     Steph     150
# 2        Meta       Wes     190
# 0       Apple      John     200
# 1      Google     April     220

# %% [markdown]
# **Sort salarys from highest to lowest**

# %%
df.sort_values('Salary', ascending=False)
# Out:
#   Corporation Employees  Salary
# 1      Google     April     220
# 0       Apple      John     200
# 2        Meta       Wes     190
# 5        Meta     Steph     150
# 3       Apple      Beth     130
# 4      Google    Justin     120

# %%
# not permanent cuz inplace is not True
df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
# inplace = True
df.sort_values('Salary', ascending=False, inplace=True)
df
# Out:
#   Corporation Employees  Salary
# 1      Google     April     220
# 0       Apple      John     200
# 2        Meta       Wes     190
# 5        Meta     Steph     150
# 3       Apple      Beth     130
# 4      Google    Justin     120

# %%
df
# Out:
#   Corporation Employees  Salary
# 1      Google     April     220
# 0       Apple      John     200
# 2        Meta       Wes     190
# 5        Meta     Steph     150
# 3       Apple      Beth     130
# 4      Google    Justin     120

# %% [markdown]
# **Sort string Alphabetically**

# %%
df.sort_values('Corporation', ascending=True)
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 3       Apple      Beth     130
# 1      Google     April     220
# 4      Google    Justin     120
# 2        Meta       Wes     190
# 5        Meta     Steph     150

# %% [markdown]
# **Sorting string Alphabetically - Descending**

# %%
df.sort_values('Corporation', ascending=False)
# Out:
#   Corporation Employees  Salary
# 2        Meta       Wes     190
# 5        Meta     Steph     150
# 1      Google     April     220
# 4      Google    Justin     120
# 0       Apple      John     200
# 3       Apple      Beth     130
