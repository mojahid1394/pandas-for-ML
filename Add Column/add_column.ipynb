# %%
import numpy as np
import pandas as pd

# %% [markdown]
# import csv file

# %%
my_df = pd.read_csv('dog_data_short.csv')
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %% [markdown]
# adding column from the list

# %%
gender = ["Male", "Female", "Male", "Male", "Female"]
my_df['Gender'] = gender
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender  Alive/Dead
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        True
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male        True
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        True

# %% [markdown]
# adding default values

# %%
my_df["Alive/Dead"] = [True]*len(my_df)
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender  Alive/Dead
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        True
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male        True
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        True

# %% [markdown]
# adding NaN values

# %%
my_df["Show Dog"] = [np.nan]*len(my_df)
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender  Alive/Dead  \
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        True
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male        True
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        True
#
#    Show Dog
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# adding columns with .insert() - Allows Position

# %%
my_df.insert(1, "Adopted", [True]*len(my_df), True)
my_df
# Out:
#                  Breed  Adopted  Adopted        Color  DogName  OwnerZip  \
# 0             COCKAPOO     True     True        BROWN  CHARLEY     15236
# 1         GER SHEPHERD     True     True  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS     True     True      BRINDLE     EICH     15238
# 3                MIXED     True     True  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER     True     True  WHITE/BROWN   OAKLEY     15139
#
#    Gender  Alive/Dead  Show Dog
# 0    Male        True       NaN
# 1  Female        True       NaN
# 2    Male        True       NaN
# 3    Male        True       NaN
# 4  Female        True       NaN

# %% [markdown]
# adding column with .assign() - creates new df

# %%
my_df2 = my_df.assign(Horse = [False]*len(my_df))
my_df2
# Out:
#                  Breed  Adopted  Adopted        Color  DogName  OwnerZip  \
# 0             COCKAPOO     True     True        BROWN  CHARLEY     15236
# 1         GER SHEPHERD     True     True  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS     True     True      BRINDLE     EICH     15238
# 3                MIXED     True     True  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER     True     True  WHITE/BROWN   OAKLEY     15139
#
#    Gender  Alive/Dead  Show Dog  Horse
# 0    Male        True       NaN  False
# 1  Female        True       NaN  False
# 2    Male        True       NaN  False
# 3    Male        True       NaN  False
# 4  Female        True       NaN  False

# %%
my_df
# Out:
#                  Breed  Adopted  Adopted        Color  DogName  OwnerZip  \
# 0             COCKAPOO     True     True        BROWN  CHARLEY     15236
# 1         GER SHEPHERD     True     True  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS     True     True      BRINDLE     EICH     15238
# 3                MIXED     True     True  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER     True     True  WHITE/BROWN   OAKLEY     15139
#
#    Gender  Alive/Dead  Show Dog
# 0    Male        True       NaN
# 1  Female        True       NaN
# 2    Male        True       NaN
# 3    Male        True       NaN
# 4  Female        True       NaN
