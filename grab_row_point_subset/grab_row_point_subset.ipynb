# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dog_data_short.csv')
df
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
df.index = ["A", "B", "C", "D", "E"]
df
# Out:
#                  Breed        Color  DogName  OwnerZip
# A             COCKAPOO        BROWN  CHARLEY     15236
# B         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# C        BELG MALINOIS      BRINDLE     EICH     15238
# D                MIXED  BLACK/BROWN    ARROW     15104
# E  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %% [markdown]
# method 1: grab row location

# %%
df.loc["B"]
# Out:
# Breed       GER SHEPHERD
# Color        BLACK/BROWN
# DogName           TACODA
# OwnerZip           15238
# Name: B, dtype: object

# %% [markdown]
# method 2: grab row index location

# %%
df.iloc[1]
# Out:
# Breed       GER SHEPHERD
# Color        BLACK/BROWN
# DogName           TACODA
# OwnerZip           15238
# Name: B, dtype: object

# %% [markdown]
# specific points(row and column)

# %%
# df.loc['Row', 'col']
df.loc["C", "DogName"]
# Out:
# 'EICH'

# %% [markdown]
# subset

# %%
# df.loc[['row', 'row'],['col', 'col']]
df.loc[['B', 'C'],['Breed', 'DogName']]
# Out:
#            Breed DogName
# B   GER SHEPHERD  TACODA
# C  BELG MALINOIS    EICH
