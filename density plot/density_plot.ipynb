# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -1.210086  0.823495 -0.990749 -1.865570
# 1   -1.173810 -1.432994 -0.019589  0.815752
# 2    1.204785  1.306958  1.178321  0.048991
# 3    1.607274 -0.789982  0.090324  0.486286
# 4    0.571801 -0.661629 -1.205171 -1.412493
# ..        ...       ...       ...       ...
# 495  0.346922  0.155505  0.174760  0.688751
# 496  0.306531 -0.550303 -0.598411 -0.275652
# 497 -0.574821  0.251261  2.384848 -2.007922
# 498  0.344103  0.376102 -0.612023 -0.762350
# 499  0.337746  0.854530 -0.398445 -0.094161
#
# [500 rows x 4 columns]

# %%
df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Mon'].plot.kde(alpha=0.4, lw=4)
# Out:
# <Axes: ylabel='Density'>

# %%
df['Mon'].plot.kde(alpha=0.4, lw=4, grid=True)
# Out:
# <Axes: ylabel='Density'>

# %%
df['Mon'].plot.kde(alpha=0.4, lw=4, grid=True, title='My KDE Plot')
# Out:
# <Axes: title={'center': 'My KDE Plot'}, ylabel='Density'>
