# %%
import pandas as pd
import numpy as np

# %% [markdown]
# pandas series like a table column

# %%
my_series = [5,9,12,27]
my_var = pd.Series(my_series)
my_var
# Out:
# 0     5
# 1     9
# 2    12
# 3    27
# dtype: int64

# %%
my_index = ["A","B","C","D"]
my_var2 = pd.Series(my_series, my_index)
my_var2
# Out:
# A     5
# B     9
# C    12
# D    27
# dtype: int64

# %%
my_var[2]
# Out:
# np.int64(12)

# %%
my_var2["B"]
# Out:
# np.int64(9)

# %%
my_var2["C"]
# Out:
# np.int64(12)

# %% [markdown]
# key value dictionary

# %%
cars = {"Tesla":26, "BMW":12, "Mercedes": 5}
my_var3 = pd.Series(cars)
my_var3
# Out:
# Tesla       26
# BMW         12
# Mercedes     5
# dtype: int64

# %%
my_var3["BMW"]
# Out:
# np.int64(12)
